# %%
# %run run_model.py
# Out:
# C:\Users\jxu2\AppData\Local\anaconda3\envs\abm_legacy\lib\site-packages\mesa\time.py:82: FutureWarning: The AgentSet is experimental. It may be changed or removed in any and all future releases, including patch releases.
# We would love to hear what you think about this new feature. If you have any thoughts, share them with us here: https://github.com/projectmesa/mesa/discussions/1919
#   self._agents: AgentSet = AgentSet(agents, model)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\trust_abm\run_model.py:5
#       2 from model import CollaborativeGovernanceModel
#       4 # 测试配置：启用中介 + 负面溢出
# ----> 5 model = CollaborativeGovernanceModel(
#       6     N=10,
#       7     trust_mechanism="broker",          # 尝试 "none", "reputation", "both"
#       8     enable_negative_spillover=True,
#       9     max_steps=50
#      10 )
#      12 # 运行模拟
# ...
